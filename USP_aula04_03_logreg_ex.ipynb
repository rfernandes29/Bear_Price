# %% [markdown]
# <a href="https://colab.research.google.com/github/rfernandes29/Bear_Price/blob/master/USP_aula04_03_logreg_ex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Regressão logística

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.datasets import make_blobs

# %%
def logistic(x):
    return 1 / (1+np.exp(-x))

# %%
#TODO: implementar
def compute_cost(X, y, w, m, eps=1e-5):
    #TODO
    J = 999
    return J

# %%
def compute_grad(X, y, w, m):
    y_hat = logistic(np.dot(X, w))
    grad = 1/m*(np.dot(X.T, y_hat - y))
    return grad

def gradient_descent(X, y, w_init, learning_rate, n_iter):
    cost_history = np.zeros((n_iter, 1))

    m = y.shape[0]
    w = np.copy(w_init)
    for i in range(n_iter):
        grad = compute_grad(X, y, w, m)
        w = w - learning_rate * grad
        cost_history[i] = compute_cost(X, y, w, m)

    return w, cost_history

# %%
X, y = make_blobs(n_samples=1000, n_features=2, centers=2, cluster_std=1, random_state=420)

m = len(y)
X = np.hstack((np.ones((m,1)),X)) # adiciona dimensão extra (bias)
y = y.reshape(-1,1)

plt.scatter(X[:,1], X[:,2], c=y[:,0])

# %%
w_init = np.zeros((X.shape[1],1))
compute_cost(X, y, w_init, len(y))
# Out:
# 999

# %%
compute_grad(X, y, w_init, len(y))
# Out:
# array([[0.        ],
#        [0.24530505],
#        [1.72110489]])

# %%
learning_rate = 0.005
iterations = 100
w, cost_history = gradient_descent(X, y, w_init, learning_rate, iterations)

plt.plot(range(len(cost_history)), cost_history, 'k')
plt.title("training curve ")
plt.xlabel("# iter")
plt.ylabel("cost")
# Out:
# Text(0, 0.5, 'cost')

# %%
a = -w[1] / w[2] # slope
b = -w[0] / w[2] # intercept

plt.scatter(X[:,1],X[:,2], c=y.reshape(-1));

x_l = np.linspace(-8, 0, 50)
y_l = a*x_l + b
plt.plot(x_l, y_l, c='k');

# %% [markdown]
# Bonus challenge!
#
# No exercício anterior as duas classes (blobs) eram linearmente separaveis. Será que o mesmo classificador funcionaria caso eles não fossem?
#
# Oque você faria para melhorar o resultado?

# %%
X, y = make_blobs(n_samples=1000, n_features=2, centers=2, cluster_std=2, random_state=420)

m = len(y)
X = np.hstack((np.ones((m,1)),X)) # adiciona dimensão extra (bias)
y = y.reshape(-1,1)

plt.scatter(X[:,1], X[:,2], c=y[:,0])
